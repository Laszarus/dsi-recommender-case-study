# %%
import pandas as pd
from surprise.model_selection import train_test_split
from surprise import Dataset, Reader
from surprise.model_selection import cross_validate
from surprise import NormalPredictor, KNNBasic, KNNWithMeans, KNNWithZScore, KNNBaseline, SVD, BaselineOnly, SVDpp, NMF, SlopeOne, CoClustering
from surprise.accuracy import rmse

# %%
df = pd.read_csv('../data/movies/ratings.csv')

# %%
df.drop('timestamp',axis=1,inplace=True)

# %%
reader = Reader(rating_scale=(0, 5))
data = Dataset.load_from_df(df,reader)

# %%
train, test = train_test_split(data, test_size=0.2)

# %% [markdown]
# ## Test Surprise Algorithms

# %%
benchmark = []
# Iterate over all algorithms
for algorithm in [SVD(), SVDpp(), SlopeOne(), NMF(), NormalPredictor(), KNNBaseline(), KNNBasic(), KNNWithMeans(), KNNWithZScore(), BaselineOnly(), CoClustering()]:
    # Perform cross validation
    results = cross_validate(algorithm, data, measures=['RMSE'], cv=3, verbose=False)
    
    # Get results & append algorithm name
    tmp = pd.DataFrame.from_dict(results).mean(axis=0)
    tmp = tmp.append(pd.Series([str(algorithm).split(' ')[0].split('.')[-1]], index=['Algorithm']))
    benchmark.append(tmp)

# %%
surprise_results = pd.DataFrame(benchmark).set_index('Algorithm').sort_values('test_rmse')

# %%
surprise_results

# %% [markdown]
# ## Using Surprise SVD++

# %%
svdpp_options = {} # adjust hyper-params here
algo = SVDpp(SVDpp_options=svdpp_options)

# %%
predictions = algo.fit(train).test(test)

# %%
accuracy.rmse(predictions)

# %% [markdown]
# ## Merging Nick & Kayla's Movie Rating Data

# %%
teach = pd.read_csv('../data/movies/g90_movie_ratings.csv')

# %%
teach.head()
# Out:
#              Name  21 Jump Street  28 Days Later  A Beautiful Mind  \
# 0    Kayla Thomas             NaN            NaN               4.0
# 1  Nick Jacobsohn             7.0            NaN               NaN
# 2          Andrew             6.0            NaN               NaN
# 3       John Herr             NaN            NaN               8.0
# 4  Jarred Bultema             6.0            6.0               8.0
#
#    About Time  Air Force One  Alien  Aliens  American Gangster  Annihilation  \
# 0        10.0            3.0    NaN     NaN                4.0           NaN
# 1         NaN            NaN   10.0     8.0                NaN           8.0
# 2         NaN            5.0    6.0     6.0                7.0           NaN
# 3         NaN            NaN    NaN     NaN                NaN           NaN
# 4         NaN            5.0    5.0     NaN                7.0           3.0
#
#    ...  The Godfather  The Intouchables  The Life Aquatic w. Steve Zissou  \
# 0  ...            NaN               NaN                               3.0
# 1  ...            NaN               NaN                               NaN
# 2  ...            NaN               NaN                               NaN
# 3  ...            8.0               NaN                               NaN
# 4  ...            NaN               NaN                               6.0
#
#    The Martian  The Pianist  Thor: Ragnarok  \
# 0          NaN          6.0             NaN
# 1          NaN          NaN             NaN
# 2          NaN          NaN             8.0
# 3          NaN          NaN             NaN
# 4          8.0          6.0            10.0
#
#    Three Billboards Outside Ebbing Missouri  Tron: Legacy  War Games  \
# 0                                       7.0           NaN        NaN
# 1                                       8.0           NaN        NaN
# 2                                       7.0           NaN        NaN
# 3                                       NaN           NaN        NaN
# 4                                       NaN           5.0        5.0
#
#    Wayne's World
# 0            2.0
# 1            7.0
# 2            NaN
# 3            NaN
# 4            7.0
#
# [5 rows x 79 columns]

# %%
teach = teach[:2]

# %%
teach
# Out:
#              Name  21 Jump Street  28 Days Later  A Beautiful Mind  \
# 0    Kayla Thomas             NaN            NaN               4.0
# 1  Nick Jacobsohn             7.0            NaN               NaN
#
#    About Time  Air Force One  Alien  Aliens  American Gangster  Annihilation  \
# 0        10.0            3.0    NaN     NaN                4.0           NaN
# 1         NaN            NaN   10.0     8.0                NaN           8.0
#
#    ...  The Godfather  The Intouchables  The Life Aquatic w. Steve Zissou  \
# 0  ...            NaN               NaN                               3.0
# 1  ...            NaN               NaN                               NaN
#
#    The Martian  The Pianist  Thor: Ragnarok  \
# 0          NaN          6.0             NaN
# 1          NaN          NaN             NaN
#
#    Three Billboards Outside Ebbing Missouri  Tron: Legacy  War Games  \
# 0                                       7.0           NaN        NaN
# 1                                       8.0           NaN        NaN
#
#    Wayne's World
# 0            2.0
# 1            7.0
#
# [2 rows x 79 columns]

# %%
class_rat = pd.read_csv('../data/movies/g99_movie_rating.csv')

# %%
class_rat.head()
# Out:
#            Name  21 Jump Street  28 Days Later  A Beautiful Mind  About Time  \
# 0  Kayla Thomas             5.0            NaN               4.0        10.0
# 1    Alex Cross             5.0            4.0               8.0         NaN
# 2     Alex Rook             NaN            6.0               NaN         NaN
# 3     Dan Reiff             6.0            NaN               NaN         NaN
# 4     Dan Riggi             7.0            3.0               7.0         NaN
#
#    Air Force One  Alien  Aliens  American Gangster  Annihilation  ...  \
# 0            3.0    NaN     NaN                4.0           NaN  ...
# 1            NaN    7.0     NaN                NaN           NaN  ...
# 2            NaN    8.0     6.0                NaN           NaN  ...
# 3            NaN    NaN     NaN                NaN           NaN  ...
# 4            7.0    8.0     6.0                9.0           NaN  ...
#
#    The Godfather  The Intouchables  The Life Aquatic w. Steve Zissou  \
# 0            NaN               NaN                               3.0
# 1            NaN               NaN                               5.0
# 2            NaN               NaN                               NaN
# 3           10.0               NaN                               NaN
# 4           10.0               NaN                               5.0
#
#    The Martian  The Pianist  Thor: Ragnarok  \
# 0          NaN          6.0             NaN
# 1          NaN          NaN             9.0
# 2          8.0          NaN             8.0
# 3          5.0          NaN             4.0
# 4          7.0          NaN             7.0
#
#    Three Billboards Outside Ebbing Missouri  Tron: Legacy  War Games  \
# 0                                       7.0           NaN        NaN
# 1                                       NaN           NaN        NaN
# 2                                       NaN           NaN        7.0
# 3                                       4.0           NaN        NaN
# 4                                       NaN           3.0        NaN
#
#    Wayne's World
# 0            2.0
# 1            NaN
# 2            6.0
# 3            NaN
# 4            4.0
#
# [5 rows x 79 columns]

# %%
cols = list(teach.columns.values)

# %%
teach.set_index(teach['Name'],inplace=True)

# %%
teach.drop(columns='Name',inplace=True)

# %%
teach.fillna(0,inplace=True)

# %%
teach = teach/2

# %%
teach
# Out:
#                 21 Jump Street  28 Days Later  A Beautiful Mind  About Time  \
# Name
# Kayla Thomas               0.0            0.0               2.0         5.0
# Nick Jacobsohn             3.5            0.0               0.0         0.0
#
#                 Air Force One  Alien  Aliens  American Gangster  Annihilation  \
# Name
# Kayla Thomas              1.5    0.0     0.0                2.0           0.0
# Nick Jacobsohn            0.0    5.0     4.0                0.0           4.0
#
#                 Apollo 13  ...  The Godfather  The Intouchables  \
# Name                       ...
# Kayla Thomas          2.0  ...            0.0               0.0
# Nick Jacobsohn        0.0  ...            0.0               0.0
#
#                 The Life Aquatic w. Steve Zissou  The Martian  The Pianist  \
# Name
# Kayla Thomas                                 1.5          0.0          3.0
# Nick Jacobsohn                               0.0          0.0          0.0
#
#                 Thor: Ragnarok  Three Billboards Outside Ebbing Missouri  \
# Name
# Kayla Thomas               0.0                                       3.5
# Nick Jacobsohn             0.0                                       4.0
#
#                 Tron: Legacy  War Games  Wayne's World
# Name
# Kayla Thomas             0.0        0.0            1.0
# Nick Jacobsohn           0.0        0.0            3.5
#
# [2 rows x 78 columns]

# %%
teach.index[0]
# Out:
# 'Kayla Thomas'

# %%
names = []
movies = []
rating = []

for idx, row in enumerate(teach.values):
    for movie, val in enumerate(row):
        if val > 0:
            #input = ','.join(name,title,val)
            names.append(teach.index[idx])
            movies.append(cols[movie])
            rating.append(val)

# %%
ratings = pd.read_csv('../data/movies/ratings.csv')

# %%
movies = pd.read_csv('../data/movies/movies.csv')

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
links = pd.read_csv('../data/movies/links.csv')

# %%
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
tags = pd.read_csv('../data/movies/tags.csv')

# %%
tags.head()
# Out:
#    userId  movieId                      tag   timestamp
# 0      15      339  sandra 'boring' bullock  1138537770
# 1      15     1955                  dentist  1193435061
# 2      15     7478                 Cambodia  1170560997
# 3      15    32892                  Russian  1170626366
# 4      15    34162              forgettable  1141391765
